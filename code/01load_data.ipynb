# %% [markdown]
# # NOTEBOOK 01: This notebook imports the raw data and returns a cleaned version of each dataset

# %%
# Importing necessary libraries for the analysis

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
## PART 1: downloading data (Justine)

# importing the dataset
educ_df = pd.read_csv("C:/Users/justi/Introduction-to-Python-S1-M1/Python-Introduction-Smoking-Prevalence/data/raw/sdg_04_10_early_educ_leavers.csv")
smoking_df =pd.read_csv("C:/Users/justi/Introduction-to-Python-S1-M1/Python-Introduction-Smoking-Prevalence/data/raw/sdg_03_30_smoking_prev.csv")

# %%
## PART 1: downloading data (Nils)

# importing the dataset
educ_df = pd.read_csv(r"C:\Users\nilsr\Desktop\Uni\Masters\z.Python\Python-Introduction-Smoking-Prevalence\data\raw\sdg_04_10_early_educ_leavers.csv")
smoking_df = pd.read_csv(r"C:\Users\nilsr\Desktop\Uni\Masters\z.Python\Python-Introduction-Smoking-Prevalence\data\raw\sdg_03_30_smoking_prev.csv")

# %%
## PART 2

#quick glance at the data
educ_df.head
smoking_df.head
# Out:
# <bound method NDFrame.head of    STRUCTURE          STRUCTURE_ID             STRUCTURE_NAME freq  \
# 0   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 1   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 2   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 3   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 4   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 5   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 6   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 7   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 8   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 9   dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 10  dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 11  dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# 12  dataflow  ESTAT:SDG_03_30(1.0)  Smoking prevalence by sex    A
# ...

# %%
# check missing values

educ_df.isnull().sum()
smoking_df.isnull().sum()
# Out:
# STRUCTURE                                  0
# STRUCTURE_ID                               0
# STRUCTURE_NAME                             0
# freq                                       0
# Time frequency                             0
# age                                        0
# Age class                                  0
# sex                                        0
# Sex                                        0
# unit                                       0
# Unit of measure                            0
# geo                                        0
# Geopolitical entity (reporting)            0
# TIME_PERIOD                                0
# Time                                      56
# OBS_VALUE                                  0
# Observation value                         56
# OBS_FLAG                                  56
# Observation status (Flag) V2 structure    56
# CONF_STATUS                               56
# Confidentiality status (flag)             56
# ...

# %%
# get information on datasets
educ_df.info()
smoking_df.info()
# educ_df : 23 columns, 70 entries, NaN in "CONF_status" and "OBS_flag"
# smoking_df : 21 columns, 56 entries, same NaN than educ_df
# weird variables types sometimes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               70 non-null     object
#  1   STRUCTURE_ID                            70 non-null     object
#  2   STRUCTURE_NAME                          70 non-null     object
#  3   freq                                    70 non-null     object
#  4   Time frequency                          70 non-null     object
#  5   unit                                    70 non-null     object
#  6   Unit of measure                         70 non-null     object
#  7   wstatus                                 70 non-null     object
#  8   Labour force and employment status      70 non-null     object
#  9   age                                     70 non-null     object
# ...

# %%
# PART 3

# keep only useful columns

useful_cols = ["STRUCTURE_NAME", "Age class", "Sex", "Unit of measure", "Geopolitical entity (reporting)", "TIME_PERIOD", "OBS_VALUE"]

educ_df = educ_df[useful_cols] 
smoking_df = smoking_df[useful_cols]

educ_df.head()
smoking_df.head()
# Out:
#               STRUCTURE_NAME         Age class      Sex  \
# 0  Smoking prevalence by sex  15 years or over  Females
# 1  Smoking prevalence by sex  15 years or over  Females
# 2  Smoking prevalence by sex  15 years or over  Females
# 3  Smoking prevalence by sex  15 years or over  Females
# 4  Smoking prevalence by sex  15 years or over  Females
#
#                   Unit of measure Geopolitical entity (reporting)  \
# 0  Percentage of total population                         Austria
# 1  Percentage of total population                         Belgium
# 2  Percentage of total population                        Bulgaria
# 3  Percentage of total population                          Cyprus
# 4  Percentage of total population                         Czechia
#
#    TIME_PERIOD  OBS_VALUE
# 0         2023         25
# 1         2023         15
# 2         2023         27
# 3         2023         24
# 4         2023         21

# %%
# cleaning the names
educ_df.columns =(educ_df.columns.str.lower().str.strip().str.replace(" ", "_"))

smoking_df.columns =(smoking_df.columns.str.lower().str.strip().str.replace(" ", "_"))

# rename / shorten some names
renames = {
    "age_class": "age",
    "geopolitical_entity_(reporting)": "geo"
}

educ_df = educ_df.rename(columns=renames)
smoking_df = smoking_df.rename(columns=renames)

print(educ_df.columns)
print(smoking_df.columns)
# Out:
# Index(['structure_name', 'age', 'sex', 'unit_of_measure', 'geo', 'time_period',
#        'obs_value'],
#       dtype='object')
# Index(['structure_name', 'age', 'sex', 'unit_of_measure', 'geo', 'time_period',
#        'obs_value'],
#       dtype='object')

# %%
# correct variable types

categorial_cols = ["age", "sex", "geo"]
educ_df[categorial_cols] = educ_df[categorial_cols].astype("category")
smoking_df[categorial_cols] = smoking_df[categorial_cols].astype("category")

educ_df.head()
smoking_df.head()
# Out:
#               structure_name               age      sex  \
# 0  Smoking prevalence by sex  15 years or over  Females
# 1  Smoking prevalence by sex  15 years or over  Females
# 2  Smoking prevalence by sex  15 years or over  Females
# 3  Smoking prevalence by sex  15 years or over  Females
# 4  Smoking prevalence by sex  15 years or over  Females
#
#                   unit_of_measure       geo  time_period  obs_value
# 0  Percentage of total population   Austria         2023         25
# 1  Percentage of total population   Belgium         2023         15
# 2  Percentage of total population  Bulgaria         2023         27
# 3  Percentage of total population    Cyprus         2023         24
# 4  Percentage of total population   Czechia         2023         21

# %%
# PART 4

# returning a clean version of the dataset (Justine)

educ_df.to_csv("C:/Users/justi/Introduction-to-Python-S1-M1/Python-Introduction-Smoking-Prevalence/data/clean_educ_df.csv")
smoking_df.to_csv("C:/Users/justi/Introduction-to-Python-S1-M1/Python-Introduction-Smoking-Prevalence/data/clean_smoking_df.csv")

# %%
# returning a clean version of the dataset (Nils)

educ_df.to_csv(r"C:\Users\nilsr\Desktop\Uni\Masters\z.Python\Python-Introduction-Smoking-Prevalence\data\clean\clean_educ_df.csv")
smoking_df.to_csv(r"C:\Users\nilsr\Desktop\Uni\Masters\z.Python\Python-Introduction-Smoking-Prevalence\data\clean\clean_smoking_df.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[73], line 3
#       1 # returning a clean version of the dataset (Nils)
# ----> 3 educ_df.to_csv(r"C:\Users\nilsr\Desktop\Uni\Masters\z.Python\Python-Introduction-Smoking-Prevalence\data\clean\clean_educ_df.csv")
#       4 smoking_df.to_csv(r"C:\Users\nilsr\Desktop\Uni\Masters\z.Python\Python-Introduction-Smoking-Prevalence\data\clean\clean_smoking_df.csv")
#
# File c:\Users\justi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# ...
